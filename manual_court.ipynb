# %%
import sys
import math
import cv2 as cv
import numpy as np

# %%
# cell 1: get image 1 minute in - in prod have to make sure nothing is covering doubles lines at that point (players)

# %%
src = cv.imread(cv.samples.findFile(filename), cv.IMREAD_GRAYSCALE)

# %%
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        raise RuntimeError(f"Failed to open video: {video_path}")

    fps = cap.get(cv2.CAP_PROP_FPS) or 30.0
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT) or 0)

    # Read first frame for playable area detection
    ret, first_frame = cap.read()
    if not ret or first_frame is None:
        cap.release()
        raise RuntimeError("Could not read first frame for playable area detection.")
# Out:
# <module 'cv2' from '/Users/ismaelrobles-razzaq/anaconda3/envs/tennis_env/lib/python3.11/site-packages/cv2/__init__.py'>
